# %% [markdown]
# # Week 9 Segmentation I (cont')

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from matplotlib.figure import Figure
from scipy import signal
from scipy.ndimage import gaussian_filter

# !wget -nc 'https://drive.google.com/uc?id=1Ku89NM5rj6O3POXLT8vlhh6xDv5AHqXG' -O cameraman.tif
# !wget -nc 'https://drive.google.com/uc?id=1ZAdq_5_Tck7h2ruGExn-8FVB1y3Ox0DE' -O 2lines.png
# !wget -nc 'https://drive.google.com/uc?id=1H3sk8nqoePFTDQd0e1CqBQ3_GvfYFXpM' -O bacteria.png
# !wget -nc 'https://drive.google.com/uc?id=1Y9yB011V9H4TwYn2kp0CUAbXsIb8rMbS' -O circle.png
# !wget -nc 'https://drive.google.com/uc?id=1DesK4q3LLaRLDi5viU-3c0C-vy8fjh1A' -O circuit1.PNG

# !wget -nc 'https://drive.google.com/uc?id=1QQFMlY8Ds4D7-AUh_g-WqWhZhiAQFwMc' -O clock2.jpg
# !wget -nc 'https://drive.google.com/uc?id=1KSPV-8X8HtNHfFF4RlT_t_hn5Trfl6K4' -O coins.jpg
# !wget -nc 'https://drive.google.com/uc?id=1jFTYRxlNDfxA0o5NIkQr97dt7b-2DmRa' -O findLine2.png
# !wget -nc 'https://drive.google.com/uc?id=12szRAjUEPWbLf_vfpItbcdBf5VAZOfz1' -O findLines.png
# !wget -nc 'https://drive.google.com/uc?id=16YXK8gHT5Sj0Tc0ggnzdbIl_sh49PHDd' -O home_cropped.jpg
# Out:
# File ‘cameraman.tif’ already there; not retrieving.
# --2023-10-11 14:39:28--  https://drive.google.com/uc?id=1ZAdq_5_Tck7h2ruGExn-8FVB1y3Ox0DE
# Resolving drive.google.com (drive.google.com)... 2404:6800:4001:80a::200e, 216.58.221.206
# Connecting to drive.google.com (drive.google.com)|2404:6800:4001:80a::200e|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0k-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/8f89gogvq7em68u17hqkup78i78qic2b/1697009925000/10800959494545164832/*/1ZAdq_5_Tck7h2ruGExn-8FVB1y3Ox0DE?uuid=8c8ff762-c452-4fe5-8a39-ffe2ed77d051 [following]
# Warning: wildcards not supported in HTTP.
# --2023-10-11 14:39:29--  https://doc-0k-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/8f89gogvq7em68u17hqkup78i78qic2b/1697009925000/10800959494545164832/*/1ZAdq_5_Tck7h2ruGExn-8FVB1y3Ox0DE?uuid=8c8ff762-c452-4fe5-8a39-ffe2ed77d051
# Resolving doc-0k-2o-docs.googleusercontent.com (doc-0k-2o-docs.googleusercontent.com)... 2404:6800:4001:810::2001, 142.250.199.33
# Connecting to doc-0k-2o-docs.googleusercontent.com (doc-0k-2o-docs.googleusercontent.com)|2404:6800:4001:810::2001|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3124 (3.1K) [image/png]
# Saving to: ‘2lines.png’
#
# 2lines.png          100%[===================>]   3.05K  --.-KB/s    in 0s
#
# 2023-10-11 14:39:29 (96.1 MB/s) - ‘2lines.png’ saved [3124/3124]
#
# --2023-10-11 14:39:29--  https://drive.google.com/uc?id=1H3sk8nqoePFTDQd0e1CqBQ3_GvfYFXpM
# Resolving drive.google.com (drive.google.com)... 2404:6800:4001:80a::200e, 216.58.221.206
# Connecting to drive.google.com (drive.google.com)|2404:6800:4001:80a::200e|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-04-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/fcnaf5erb96ui4082204ohdfqnf74peq/1697009925000/10800959494545164832/*/1H3sk8nqoePFTDQd0e1CqBQ3_GvfYFXpM?uuid=2201f7f8-7d9c-4f68-a734-3a31db9e23c2 [following]
# Warning: wildcards not supported in HTTP.
# --2023-10-11 14:39:30--  https://doc-04-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/fcnaf5erb96ui4082204ohdfqnf74peq/1697009925000/10800959494545164832/*/1H3sk8nqoePFTDQd0e1CqBQ3_GvfYFXpM?uuid=2201f7f8-7d9c-4f68-a734-3a31db9e23c2
# Resolving doc-04-2o-docs.googleusercontent.com (doc-04-2o-docs.googleusercontent.com)... 2404:6800:4001:802::2001, 142.251.223.65
# Connecting to doc-04-2o-docs.googleusercontent.com (doc-04-2o-docs.googleusercontent.com)|2404:6800:4001:802::2001|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48604 (47K) [image/png]
# Saving to: ‘bacteria.png’
#
# bacteria.png        100%[===================>]  47.46K  --.-KB/s    in 0.05s
#
# 2023-10-11 14:39:30 (987 KB/s) - ‘bacteria.png’ saved [48604/48604]
#
# --2023-10-11 14:39:30--  https://drive.google.com/uc?id=1Y9yB011V9H4TwYn2kp0CUAbXsIb8rMbS
# Resolving drive.google.com (drive.google.com)... 2404:6800:4001:80a::200e, 216.58.221.206
# Connecting to drive.google.com (drive.google.com)|2404:6800:4001:80a::200e|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0k-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/0ta6ou2f6bfj6tqhguebg313cese3umt/1697009925000/10800959494545164832/*/1Y9yB011V9H4TwYn2kp0CUAbXsIb8rMbS?uuid=c90b1f0f-8e16-4e8b-aaa6-093a5fb79e09 [following]
# Warning: wildcards not supported in HTTP.
# --2023-10-11 14:39:31--  https://doc-0k-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/0ta6ou2f6bfj6tqhguebg313cese3umt/1697009925000/10800959494545164832/*/1Y9yB011V9H4TwYn2kp0CUAbXsIb8rMbS?uuid=c90b1f0f-8e16-4e8b-aaa6-093a5fb79e09
# Resolving doc-0k-2o-docs.googleusercontent.com (doc-0k-2o-docs.googleusercontent.com)... 2404:6800:4001:80b::2001, 142.251.223.65
# Connecting to doc-0k-2o-docs.googleusercontent.com (doc-0k-2o-docs.googleusercontent.com)|2404:6800:4001:80b::2001|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1306 (1.3K) [image/png]
# Saving to: ‘circle.png’
#
# circle.png          100%[===================>]   1.28K  --.-KB/s    in 0s
#
# 2023-10-11 14:39:31 (54.2 MB/s) - ‘circle.png’ saved [1306/1306]
#
# --2023-10-11 14:39:31--  https://drive.google.com/uc?id=1DesK4q3LLaRLDi5viU-3c0C-vy8fjh1A
# Resolving drive.google.com (drive.google.com)... 2404:6800:4001:80a::200e, 216.58.221.206
# Connecting to drive.google.com (drive.google.com)|2404:6800:4001:80a::200e|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/0jmjnmn7bih8s2v2n4tuug3rggqf2231/1697009925000/10800959494545164832/*/1DesK4q3LLaRLDi5viU-3c0C-vy8fjh1A?uuid=b424603e-7654-49d5-9072-89caa83bd0d2 [following]
# Warning: wildcards not supported in HTTP.
# --2023-10-11 14:39:32--  https://doc-0s-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/0jmjnmn7bih8s2v2n4tuug3rggqf2231/1697009925000/10800959494545164832/*/1DesK4q3LLaRLDi5viU-3c0C-vy8fjh1A?uuid=b424603e-7654-49d5-9072-89caa83bd0d2
# Resolving doc-0s-2o-docs.googleusercontent.com (doc-0s-2o-docs.googleusercontent.com)... 2404:6800:4001:80b::2001, 172.217.26.65
# Connecting to doc-0s-2o-docs.googleusercontent.com (doc-0s-2o-docs.googleusercontent.com)|2404:6800:4001:80b::2001|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3261 (3.2K) [image/png]
# Saving to: ‘circuit1.PNG’
#
# circuit1.PNG        100%[===================>]   3.18K  --.-KB/s    in 0.001s
#
# 2023-10-11 14:39:32 (2.13 MB/s) - ‘circuit1.PNG’ saved [3261/3261]
#
# --2023-10-11 14:39:33--  https://drive.google.com/uc?id=1QQFMlY8Ds4D7-AUh_g-WqWhZhiAQFwMc
# Resolving drive.google.com (drive.google.com)... 2404:6800:4001:80a::200e, 216.58.221.206
# Connecting to drive.google.com (drive.google.com)|2404:6800:4001:80a::200e|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0c-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/82u502a5ssb05s8g95kgtbjfngevk9rt/1697009925000/10800959494545164832/*/1QQFMlY8Ds4D7-AUh_g-WqWhZhiAQFwMc?uuid=bfe5587d-3a2d-4aef-a85b-8b5667aa5884 [following]
# Warning: wildcards not supported in HTTP.
# --2023-10-11 14:39:33--  https://doc-0c-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/82u502a5ssb05s8g95kgtbjfngevk9rt/1697009925000/10800959494545164832/*/1QQFMlY8Ds4D7-AUh_g-WqWhZhiAQFwMc?uuid=bfe5587d-3a2d-4aef-a85b-8b5667aa5884
# Resolving doc-0c-2o-docs.googleusercontent.com (doc-0c-2o-docs.googleusercontent.com)... 2404:6800:4001:810::2001, 142.251.223.65
# Connecting to doc-0c-2o-docs.googleusercontent.com (doc-0c-2o-docs.googleusercontent.com)|2404:6800:4001:810::2001|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39177 (38K) [image/jpeg]
# Saving to: ‘clock2.jpg’
#
# clock2.jpg          100%[===================>]  38.26K  --.-KB/s    in 0.04s
#
# 2023-10-11 14:39:34 (921 KB/s) - ‘clock2.jpg’ saved [39177/39177]
#
# --2023-10-11 14:39:34--  https://drive.google.com/uc?id=1KSPV-8X8HtNHfFF4RlT_t_hn5Trfl6K4
# Resolving drive.google.com (drive.google.com)... 2404:6800:4001:80a::200e, 216.58.221.206
# Connecting to drive.google.com (drive.google.com)|2404:6800:4001:80a::200e|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-04-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/jrkghau85ssl0144sn2d80jvo472nfu3/1697009925000/10800959494545164832/*/1KSPV-8X8HtNHfFF4RlT_t_hn5Trfl6K4?uuid=761790b6-46ef-4f29-b593-7af27895b3db [following]
# Warning: wildcards not supported in HTTP.
# --2023-10-11 14:39:34--  https://doc-04-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/jrkghau85ssl0144sn2d80jvo472nfu3/1697009925000/10800959494545164832/*/1KSPV-8X8HtNHfFF4RlT_t_hn5Trfl6K4?uuid=761790b6-46ef-4f29-b593-7af27895b3db
# Resolving doc-04-2o-docs.googleusercontent.com (doc-04-2o-docs.googleusercontent.com)... 2404:6800:4001:810::2001, 142.251.223.65
# Connecting to doc-04-2o-docs.googleusercontent.com (doc-04-2o-docs.googleusercontent.com)|2404:6800:4001:810::2001|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16322 (16K) [image/jpeg]
# Saving to: ‘coins.jpg’
#
# coins.jpg           100%[===================>]  15.94K  --.-KB/s    in 0.01s
#
# 2023-10-11 14:39:35 (1.55 MB/s) - ‘coins.jpg’ saved [16322/16322]
#
# --2023-10-11 14:39:35--  https://drive.google.com/uc?id=1jFTYRxlNDfxA0o5NIkQr97dt7b-2DmRa
# Resolving drive.google.com (drive.google.com)... 2404:6800:4001:80a::200e, 216.58.221.206
# Connecting to drive.google.com (drive.google.com)|2404:6800:4001:80a::200e|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-00-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/3n4935l7gmuot7hvmmumrtijgm0j0fuh/1697009925000/10800959494545164832/*/1jFTYRxlNDfxA0o5NIkQr97dt7b-2DmRa?uuid=713247ca-421b-4e78-8763-d092ce0058d9 [following]
# Warning: wildcards not supported in HTTP.
# --2023-10-11 14:39:36--  https://doc-00-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/3n4935l7gmuot7hvmmumrtijgm0j0fuh/1697009925000/10800959494545164832/*/1jFTYRxlNDfxA0o5NIkQr97dt7b-2DmRa?uuid=713247ca-421b-4e78-8763-d092ce0058d9
# Resolving doc-00-2o-docs.googleusercontent.com (doc-00-2o-docs.googleusercontent.com)... 2404:6800:4001:810::2001, 142.250.199.1
# Connecting to doc-00-2o-docs.googleusercontent.com (doc-00-2o-docs.googleusercontent.com)|2404:6800:4001:810::2001|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 142701 (139K) [image/png]
# Saving to: ‘findLine2.png’
#
# findLine2.png       100%[===================>] 139.36K  --.-KB/s    in 0.09s
#
# 2023-10-11 14:39:37 (1.53 MB/s) - ‘findLine2.png’ saved [142701/142701]
#
# --2023-10-11 14:39:37--  https://drive.google.com/uc?id=12szRAjUEPWbLf_vfpItbcdBf5VAZOfz1
# Resolving drive.google.com (drive.google.com)... 2404:6800:4001:80a::200e, 216.58.221.206
# Connecting to drive.google.com (drive.google.com)|2404:6800:4001:80a::200e|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-10-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/l7atdcuc9jie1eo3fgtknpuu6r04kp93/1697009925000/10800959494545164832/*/12szRAjUEPWbLf_vfpItbcdBf5VAZOfz1?uuid=e0e489c8-ec90-46d8-a240-7c113843bd73 [following]
# Warning: wildcards not supported in HTTP.
# --2023-10-11 14:39:37--  https://doc-10-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/l7atdcuc9jie1eo3fgtknpuu6r04kp93/1697009925000/10800959494545164832/*/12szRAjUEPWbLf_vfpItbcdBf5VAZOfz1?uuid=e0e489c8-ec90-46d8-a240-7c113843bd73
# Resolving doc-10-2o-docs.googleusercontent.com (doc-10-2o-docs.googleusercontent.com)... 2404:6800:4001:802::2001, 142.250.199.1
# Connecting to doc-10-2o-docs.googleusercontent.com (doc-10-2o-docs.googleusercontent.com)|2404:6800:4001:802::2001|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 133361 (130K) [image/png]
# Saving to: ‘findLines.png’
#
# findLines.png       100%[===================>] 130.24K  --.-KB/s    in 0.08s
#
# 2023-10-11 14:39:38 (1.66 MB/s) - ‘findLines.png’ saved [133361/133361]
#
# --2023-10-11 14:39:38--  https://drive.google.com/uc?id=16YXK8gHT5Sj0Tc0ggnzdbIl_sh49PHDd
# Resolving drive.google.com (drive.google.com)... 2404:6800:4001:80a::200e, 216.58.221.206
# Connecting to drive.google.com (drive.google.com)|2404:6800:4001:80a::200e|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-04-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/7mqn9iue1dl0otbg0b5e3tg9i1vj4jd0/1697009925000/10800959494545164832/*/16YXK8gHT5Sj0Tc0ggnzdbIl_sh49PHDd?uuid=2afc6757-94c4-4568-87ad-e25fa1c2d70e [following]
# Warning: wildcards not supported in HTTP.
# --2023-10-11 14:39:39--  https://doc-04-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/7mqn9iue1dl0otbg0b5e3tg9i1vj4jd0/1697009925000/10800959494545164832/*/16YXK8gHT5Sj0Tc0ggnzdbIl_sh49PHDd?uuid=2afc6757-94c4-4568-87ad-e25fa1c2d70e
# Resolving doc-04-2o-docs.googleusercontent.com (doc-04-2o-docs.googleusercontent.com)... 2404:6800:4001:802::2001, 172.217.26.65
# Connecting to doc-04-2o-docs.googleusercontent.com (doc-04-2o-docs.googleusercontent.com)|2404:6800:4001:802::2001|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8353 (8.2K) [image/jpeg]
# Saving to: ‘home_cropped.jpg’
#
# home_cropped.jpg    100%[===================>]   8.16K  --.-KB/s    in 0.006s
#
# 2023-10-11 14:39:39 (1.43 MB/s) - ‘home_cropped.jpg’ saved [8353/8353]

# %% [markdown]
# ## Hough Line transform
# * https://docs.opencv.org/3.4/d9/db0/tutorial_hough_lines.html

# %% [markdown]
# ### Example #1

# %%
# HoughLines transforms
img = cv2.imread('2lines.png')
plt.imshow(img)
plt.show()

gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray,50,150,apertureSize = 3)
lines = cv2.HoughLines(edges,10,np.pi/180,200)

# # Convert radian to degree
linesdegree = lines.copy()
linesdegree[:,0:1,1:2] =linesdegree[:,0:1,1:2]*180/np.pi

# plt.imshow(img)
# plt.show()
# # use scatter plot
for i in range(0,2):#len(linesdegree)):
	plt.scatter(linesdegree[i,0:1,1:2],linesdegree[i,0:1,0:1])

# # set x,y limits
plt.xlim(0, 180)
plt.ylim(-100*np.sqrt(2), 100*np.sqrt(2))
plt.show()

# %% [markdown]
# ### Exercise #1

# %%
img = cv2.imread('clock2.jpg')
plt.imshow(img)
plt.show()



gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
m,n = gray.shape
edges = cv2.Canny(gray,50,150,apertureSize = 3)
lines = cv2.HoughLines(edges,10,np.pi/180,500)
print(lines)
# # Convert radian to degree
linesdegree = lines.copy()
linesdegree[:,0:1,1:2] =linesdegree[:,0:1,1:2]*180/np.pi

# plt.imshow(img)
# plt.show()
# # use scatter plot
for i in range(0,len(linesdegree)):
	plt.scatter(linesdegree[i,0:1,1:2],linesdegree[i,0:1,0:1])

# # set x,y limits
plt.xlim(0, 180)
plt.ylim(-m*np.sqrt(2), m*np.sqrt(2))
plt.show()
# Out:
# [[[555.          1.0471976]]
#
#  [[155.          2.0943952]]
#
#  [[535.          1.0471976]]]

# %% [markdown]
# ## Hough circle transform
# * https://docs.opencv.org/4.x/da/d53/tutorial_py_houghcircles.html

# %%
img = cv2.imread('clock2.jpg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

edges = cv2.Canny(gray,50,150,apertureSize = 3)
circles = cv2.HoughCircles(edges,cv2.HOUGH_GRADIENT,1,500,
                            param1=50,param2=30,minRadius=200)

circles = np.uint16(np.around(circles))
for i in circles[0,:]:
    # draw the outer circle
    cv2.circle(img,(i[0],i[1]),i[2],(255,0,0),2)
    # draw the center of the circle
    cv2.circle(img,(i[0],i[1]),2,(0,0,255),3)

plt.imshow(img)
plt.show()

# %% [markdown]
# ## Threshold

# %%
img = cv2.imread("bacteria.png",0)
ret,thresh1 = cv2.threshold(img,123,255,cv2.THRESH_BINARY)

plt.subplot(1,2,1),plt.imshow(img,'gray')
plt.title("Original")
plt.subplot(1,2,2),plt.imshow(thresh1,'gray')
plt.title("Threshold image")
plt.show()



# ret,thresh1 = cv2.threshold(img,_________,255,cv2.THRESH_BINARY)

# %%
img = cv2.imread("bacteria.png",0)
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,21,0)
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,21,0)

# %% [markdown]
# ### Otsu's
# * https://docs.opencv.org/4.x/d7/d4d/tutorial_py_thresholding.html

# %%
img = cv2.imread("bacteria.png",0)

ret,thresh1 = cv2.threshold(img,0,255,cv2.THRESH_OTSU)

plt.imshow(thresh1,cmap='gray')
plt.show()

# %% [markdown]
# ## Region Growing

# %% [markdown]
# * https://docs.opencv.org/4.x/d3/db4/tutorial_py_watershed.html

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img = cv2.imread('coins.jpg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
plt.imshow(thresh);plt.show()


# Finding sure foreground area
dist_transform = cv2.distanceTransform(thresh,cv2.DIST_L2,5)
ret, sure_fg = cv2.threshold(dist_transform,0.7*dist_transform.max(),255,cv2.THRESH_BINARY)
plt.imshow(sure_fg);plt.title("sure_fg");plt.show()
# Finding unknown region
sure_fg = np.uint8(sure_fg)
unknown = cv2.subtract(thresh,sure_fg)

# Marker labelling
ret, markers = cv2.connectedComponents(sure_fg)
# Add one to all labels so that sure background is not 0, but 1
markers = markers+1
# Now, mark the region of unknown with zero
markers[unknown==255] = 0


markers = cv2.watershed(img,markers)
img[markers == -1] = [255,0,0] # BGR

plt.imshow(img[:,:,::-1]);plt.show()
plt.imshow(markers);plt.colorbar();plt.title("Marker");plt.show()
